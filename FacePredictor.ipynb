# %%
import cv2
import os
from AllFunction import *
#Haarcascade model for face detection
model_har = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
#Load model for face detection
Srasthy_model = cv2.face_LBPHFaceRecognizer.create()
Srasthy_model.read('./Srasthy_model.h5')
#function to crop the face
def cropface(img):
    
    # Convert image to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = model_har.detectMultiScale(gray, 1.3, 5)
    if faces is ():
        return img
     
    for (x,y,w,h) in faces:
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,255),2)
        cropped = img[y:y+h, x:x+w]
    return cropped

#capturing Srasthy face
cap = cv2.VideoCapture(0)
ret, myframe = cap.read()

#crop image
myface_cropimage = cropface(myframe)

#change color of image to gray color 
myface_cropimage = cv2.cvtColor(myface_cropimage,cv2.COLOR_BGR2GRAY)

#resizing the image
myface_cropimage = cv2.resize(myface_cropimage,(200,200))

#showing my image
cv2.imshow("my crop photo",myface_cropimage)
cv2.waitKey()
cv2.destroyAllWindows()

#myface stroing into file
cv2.imwrite("pic.jpg",myface_cropimage)

#release camera
cap.release()

# predicting the result of Srasthy face
Srasthy_myface = Srasthy_model.predict(myface_cropimage)

#printing prediction result value for my face
print("Result value for my face : " , Srasthy_face)

#confidence value for my face
Srasthy_confidence = int( 100 * (1 - (Srasthy_facee[1])/400) )
print("Confidence value for my face : " , Srasthy_confidence)

if Srasthy_confidence >= 80:
    print("sending whatsapp message")
    whatsapp_msg_sent()
    print("whatsapp message sent successful")
    
    print("sending mail")
    email_sent()
    print("mail sent successful")

else:
    print("Launching infrastructure by terraform")
    os.system("terraform init")
    os.system("terraform apply --auto-approve")
    print("Infrastructure launched successfully by Terraform..!!")
    print("launching ec2 instance")
    ec2_launch()
    print("launched ec2 instance")
    print("creating ebs volume")
    ebs_launch()
    print("launched ebs volume")
